# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import json

# %%
games = pd.read_json("../data/games_2021.json")
teams = pd.read_json('../data/big_10_teams_2021.json')
df = pd.merge(teams, games)

for index, row in df.iterrows():
    for team in row['teams']:
        
        # find home and away teams        
        if team['homeAway'] == 'home':
            # add home teams
            df.loc[index, 'home_team'] = team['school']
            for i in team['stats']:
                # add home stats
                stats = ('home_' + i['category'], i['stat'])
                df.loc[index, stats[0]] = stats[1]

        if team['homeAway'] == 'away':
            # add away teams
            df.loc[index, 'away_team'] = team['school']
            for i in team['stats']:
                # add away stats
                stats = ('away_' + i['category'], i['stat'])
                df.loc[index, stats[0]] = stats[1]

# Move home and away team columns to begininng
first_column = df.pop('home_team')
df.insert(1, 'home_team', first_column)

second_column = df.pop('away_team')
df.insert(2, 'away_team', second_column)

# Drop 'teams' columns
df = df.drop('teams', axis=1)

# First row of df
df.iloc[0].dropna()
# Out:
# id                      401331447
# home_team                    Iowa
# away_team                Michigan
# season                       2021
# week                           14
#                           ...
# home_netPassingYards          175
# home_totalYards               279
# home_fourthDownEff            0-1
# home_thirdDownEff            5-19
# home_firstDowns                15
# Name: 0, Length: 93, dtype: object

# %%
df = df[df.home_conference == 'Big Ten']
df = df[df.away_conference == 'Big Ten']

df = df[df["home_points"].notna()]
df = df[df["away_points"].notna()]
df = df[df["home_interceptionYards"].notna()]

# Makes a new column called "home_win" with value True
# if home_points is greater than away_points, False otherwise 
df["home_win"] = df["home_points"] > df["away_points"]

# %%
f = open("../data/2021_stats_advanced.json")
advanced_stats = json.load(f)

# %%
team_to_plays = {}
team_to_line_yards = {}
team_to_points_per_opportunity = {}

for dict in advanced_stats:
    team_to_plays[dict["team"]] = dict["offense"]["plays"]
    team_to_line_yards[dict["team"]] = dict["offense"]["lineYards"]
    team_to_points_per_opportunity[dict["team"]] = dict["offense"]["pointsPerOpportunity"]

# %%
df['home_plays'] = df['home_team'].map(team_to_plays)
df['away_plays'] = df['away_team'].map(team_to_plays)

df['home_line_yards'] = df['home_team'].map(team_to_line_yards)
df['away_line_yards'] = df['away_team'].map(team_to_line_yards)

df['home_points_per_opportunity'] = df['home_team'].map(team_to_points_per_opportunity)
df['away_points_per_opportunity'] = df['away_team'].map(team_to_points_per_opportunity)

df
# Out:
#            id       home_team       away_team  season  week season_type  \
# 0   401331447            Iowa        Michigan    2021    14     regular
# 10  401282731         Indiana  Michigan State    2021     7     regular
# 14  401282818      Penn State         Rutgers    2021    12     regular
# 16  401282721            Iowa        Illinois    2021    12     regular
# 19  401282803       Wisconsin        Nebraska    2021    12     regular
# 21  401282717      Penn State        Illinois    2021     8     regular
# 22  401282824         Rutgers       Wisconsin    2021    10     regular
# 25  401282787          Purdue  Michigan State    2021    10     regular
# 26  401282788         Rutgers  Michigan State    2021     6     regular
# 27  401282779        Michigan    Northwestern    2021     8     regular
# 32  401282718        Illinois       Wisconsin    2021     6     regular
# 35  401282769      Ohio State        Maryland    2021     6     regular
# 39  401282806       Wisconsin    Northwestern    2021    11     regular
# 41  401282771  Michigan State        Maryland    2021    11     regular
# 42  401282777  Michigan State        Michigan    2021     9     regular
# 44  401282722        Illinois    Northwestern    2021    13     regular
# 45  401282814      Ohio State      Penn State    2021     9     regular
# 46  401282753          Purdue         Indiana    2021    13     regular
# 49  401282794       Minnesota       Wisconsin    2021    13     regular
# 53  401282795    Northwestern       Minnesota    2021     9     regular
# 56  401282778        Nebraska        Michigan    2021     6     regular
# 58  401282758            Iowa      Penn State    2021     6     regular
# 59  401282776       Wisconsin        Michigan    2021     5     regular
# 60  401282799        Nebraska      Ohio State    2021    10     regular
# 67  401282723            Iowa         Indiana    2021     1     regular
# 69  401282789       Minnesota      Ohio State    2021     1     regular
# 82  401282784  Michigan State        Nebraska    2021     4     regular
# 95  401282729      Penn State         Indiana    2021     5     regular
#
#                   start_date  start_time_tbd  neutral_site  conference_game  \
# 0   2021-12-05T01:00:00.000Z           False          True             True
# 10  2021-10-16T16:00:00.000Z           False         False             True
# 14  2021-11-20T17:00:00.000Z           False         False             True
# 16  2021-11-20T19:00:00.000Z           False         False             True
# 19  2021-11-20T20:30:00.000Z           False         False             True
# 21  2021-10-23T16:00:00.000Z           False         False             True
# 22  2021-11-06T19:30:00.000Z           False         False             True
# 25  2021-11-06T19:30:00.000Z           False         False             True
# 26  2021-10-09T16:00:00.000Z           False         False             True
# 27  2021-10-23T16:00:00.000Z           False         False             True
# 32  2021-10-09T19:30:00.000Z           False         False             True
# 35  2021-10-09T16:00:00.000Z           False         False             True
# 39  2021-11-13T17:00:00.000Z           False         False             True
# 41  2021-11-13T21:00:00.000Z           False         False             True
# 42  2021-10-30T16:00:00.000Z           False         False             True
# 44  2021-11-27T20:30:00.000Z           False         False             True
# 45  2021-10-30T23:30:00.000Z           False         False             True
# 46  2021-11-27T20:30:00.000Z           False         False             True
# 49  2021-11-27T21:00:00.000Z           False         False             True
# 53  2021-10-30T19:30:00.000Z           False         False             True
# 56  2021-10-09T23:30:00.000Z           False         False             True
# 58  2021-10-09T20:00:00.000Z           False         False             True
# 59  2021-10-02T16:00:00.000Z           False         False             True
# 60  2021-11-06T16:00:00.000Z           False         False             True
# 67  2021-09-04T19:30:00.000Z           False         False             True
# 69  2021-09-03T00:00:00.000Z           False         False             True
# 82  2021-09-25T23:00:00.000Z           False         False             True
# 95  2021-10-02T23:30:00.000Z           False         False             True
#
#     ...  away_kickReturnYards  away_kickReturnTDs away_kickReturns  home_win  \
# 0   ...                   NaN                 NaN              NaN     False
# 10  ...                    32                   0                3     False
# 14  ...                   NaN                 NaN              NaN      True
# 16  ...                     0                   0                3      True
# 19  ...                    40                   0                3      True
# 21  ...                   NaN                 NaN              NaN     False
# 22  ...                     0                   0                1     False
# 25  ...                    21                   0                4      True
# 26  ...                    10                   0                1     False
# 27  ...                    46                   0                3      True
# 32  ...                   NaN                 NaN              NaN     False
# 35  ...                    65                   0                3      True
# 39  ...                    43                   0                2      True
# 41  ...                    66                   0                4      True
# 42  ...                    38                   0                2      True
# 44  ...                    17                   0                1      True
# 45  ...                     0                   0                1      True
# 46  ...                    54                   0                4      True
# 49  ...                    55                   0                3      True
# 53  ...                     0                   0                2     False
# 56  ...                    57                   0                3     False
# 58  ...                   NaN                 NaN              NaN      True
# 59  ...                     3                   0                1     False
# 60  ...                    24                   0                2     False
# 67  ...                   NaN                 NaN              NaN      True
# 69  ...                    19                   0                1     False
# 82  ...                    13                   0                1      True
# 95  ...                   NaN                 NaN              NaN      True
#
#    home_plays away_plays  home_line_yards away_line_yards  \
# 0         895        948         2.633333        3.211636
# 10        817        855         2.712750        2.952164
# 14        964        887         2.700708        3.120502
# 16        895        853         2.633333        3.354694
# 19        851        825         3.212754        3.137255
# 21        964        853         2.700708        3.354694
# 22        887        851         3.120502        3.212754
# 25        947        855         2.793372        2.952164
# 26        887        855         3.120502        2.952164
# 27        948        802         3.211636        2.861667
# 32        853        851         3.354694        3.212754
# 35        914        918         3.350985        3.053186
# 39        851        802         3.212754        2.861667
# 41        855        918         2.952164        3.053186
# 42        855        948         2.952164        3.211636
# 44        853        802         3.354694        2.861667
# 45        914        964         3.350985        2.700708
# 46        947        817         2.793372        2.712750
# 49        847        851         3.155979        3.212754
# 53        802        847         2.861667        3.155979
# 56        825        948         3.137255        3.211636
# 58        895        964         2.633333        2.700708
# 59        851        948         3.212754        3.211636
# 60        825        914         3.137255        3.350985
# 67        895        817         2.633333        2.712750
# 69        847        914         3.155979        3.350985
# 82        855        825         2.952164        3.137255
# 95        964        817         2.700708        2.712750
#
#     home_points_per_opportunity  away_points_per_opportunity
# 0                      3.000000                     4.153846
# 10                     3.442308                     3.777778
# 14                     3.454545                     3.409091
# 16                     3.000000                     3.158730
# 19                     3.071429                     3.972603
# 21                     3.454545                     3.158730
# 22                     3.409091                     3.071429
# 25                     3.925000                     3.777778
# 26                     3.409091                     3.777778
# 27                     4.153846                     2.965517
# 32                     3.158730                     3.071429
# 35                     4.880435                     3.797619
# 39                     3.071429                     2.965517
# 41                     3.777778                     3.797619
# 42                     3.777778                     4.153846
# 44                     3.158730                     2.965517
# 45                     4.880435                     3.454545
# 46                     3.925000                     3.442308
# 49                     3.734940                     3.071429
# 53                     2.965517                     3.734940
# 56                     3.972603                     4.153846
# 58                     3.000000                     3.454545
# 59                     3.071429                     4.153846
# 60                     3.972603                     4.880435
# 67                     3.000000                     3.442308
# 69                     3.734940                     4.880435
# 82                     3.777778                     3.972603
# 95                     3.454545                     3.442308
#
# [28 rows x 109 columns]

# %%
columns = ["home_plays", "away_plays", "home_line_yards", "away_line_yards", "home_points_per_opportunity", "away_points_per_opportunity"]

X = df[columns]
y = df["home_win"]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

clf = SVC(kernel='linear', C = 1.0)
clf.fit(X_train, y_train)
# score_train = clf.score(X_train, y_train)
score_test = clf.score(X_test, y_test)
score_test
# Out:
# 0.42857142857142855

# %%
home = "Rutgers"
away = "Michigan"
todays_game = [team_to_plays[home], team_to_plays[away], 
               team_to_line_yards[home], team_to_line_yards[away], 
               team_to_points_per_opportunity[home], team_to_points_per_opportunity[away]]

clf.predict([todays_game])
# Out:
# /Users/leena/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([ True])
